# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "/content/drive/MyDrive/조코딩해커톤"

# %%
# !git clone https://github.com/subrtade662/hairstyle_transfer.git
# %cd hairstyle_transfer

# %%
# !pip install -r requirements.txt

# %%
# !ls

# %%
# !pip install opencv-python==4.1.2.30
# !pip install face_alignment==1.3.5
# !pip install scikit-learn==1.0.2
# !pip install scikit-image==0.18.3

# %%
# !python inference.py --output_path /content/drive/MyDrive/조코딩해커톤/output/hairstyle_transfer \
--mode interp \
--source /content/drive/MyDrive/조코딩해커톤/1.jpg \
--target /content/drive/MyDrive/조코딩해커톤/2.jpg  \
--nsteps 20 \
[--interpolate_face] \
[--alpha_blend]
