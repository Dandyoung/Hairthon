# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "/content/drive/MyDrive/조코딩해커톤"
# Out:
# /content/drive/MyDrive/조코딩해커톤

# %%
# !git clone https://github.com/Taeu/Style-Your-Hair.git
# Out:
# fatal: destination path 'Style-Your-Hair' already exists and is not an empty directory.

# %%
# Style-Your-Hair 위치로 들어가기
# %cd Style-Your-Hair
# Out:
# /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair

# %%
import torch
import numpy

if torch.cuda.is_available():
    device = torch.cuda.get_device_name(0)  # 0번 GPU의 이름을 가져옵니다. 여러 개의 GPU가 있는 경우에는 원하는 GPU의 인덱스를 넣으면 됩니다.
    print("CUDA is available. Using GPU:", device)
else:
    print("No CUDA devices found. Using CPU.")
# Out:
# CUDA is available. Using GPU: Tesla T4

# %%
# !pip install face_alignment face-recognition gdown ipython matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.0 MB/s eta 0:00:00
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566169 sha256=a27478d064320084af445ed55befd11e5d8f69b86d938168bc7793e58573937f
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
# !pip install --upgrade face-recognition-models

# %%
# !pip uninstall dlib -y
# Out:
# Found existing installation: dlib 19.24.2
# Uninstalling dlib-19.24.2:
#   Successfully uninstalled dlib-19.24.2

# %%
# !git clone https://github.com/davisking/dlib.git
# %cd dlib
# !mkdir build
# %cd build
# !cmake .. -DDLIB_USE_CUDA=0 -DUSE_AVX_INSTRUCTIONS=1
# !cmake --build .
# !sudo make install
# !sudo ldconfig
# %cd ..
# !python setup.py build --no DLIB_USE_CUDA
# !python setup.py install --no DLIB_USE_CUDA
# Out:
# fatal: destination path 'dlib' already exists and is not an empty directory.
# /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair/dlib
# mkdir: cannot create directory ‘build’: File exists
# /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair/dlib/build
# -- Using CMake version: 3.25.2
# -- Compiling dlib version: 19.24.99
# -- Enabling AVX instructions
# -- Found system copy of libpng: /usr/lib/x86_64-linux-gnu/libpng.so;/usr/lib/x86_64-linux-gnu/libz.so
# -- Found system copy of libjpeg: /usr/lib/x86_64-linux-gnu/libjpeg.so
# -- Searching for BLAS and LAPACK
# -- Searching for BLAS and LAPACK
# -- Checking for module 'cblas'
# --   No package 'cblas' found
# -- Found Intel MKL BLAS/LAPACK library
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair/dlib/build
# [ 96%] Built target dlib
# /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair/dlib
# running install
# ...

# %%
# !pip install ninja
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 3.2 MB/s eta 0:00:00
# ...

# %%
cd "/content/drive/MyDrive/조코딩해커톤/Style-Your-Hair"
# Out:
# /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair

# %%
# !python main.py --input_dir /content/drive/MyDrive/조코딩해커톤/ --im_path1 1.jpg --im_path2 2.jpg \
    --output_dir /content/drive/MyDrive/조코딩해커톤/output/ \
    --warp_loss_with_prev_list delta_w style_hair_slic_large \
    --save_all --version final --flip_check
# Out:
# hi
# Loading StyleGAN2 from checkpoint: pretrained_models/ffhq.pt
# torch.Size([512])
# Setting up Perceptual loss...
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /content/drive/MyDrive/조코딩해커톤/Style-Your-Hair/losses/lpips/weights/v0.1/vgg.pth
# ...[net-lin [vgg]] initialized
# ...Done
# /content/drive/MyDrive/조코딩해커톤/1.jpg
# /content/drive/MyDrive/조코딩해커톤/2.jpg
# ...

# %%
import time
import subprocess

start_time = time.time()

# main.py를 실행합니다.
subprocess.run([
    'python', 'main.py',
    '--input_dir', '/content/drive/MyDrive/조코딩해커톤/',
    '--im_path1', '4.jpg',
    '--im_path2', '3.jpg',
    '--output_dir', '/content/drive/MyDrive/조코딩해커톤/output/',
    '--warp_loss_with_prev_list', 'delta_w', 'style_hair_slic_large',
    '--save_all', '--version', 'final', '--flip_check'
])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"스크립트 실행에 걸린 시간: {elapsed_time:.2f} 초")
